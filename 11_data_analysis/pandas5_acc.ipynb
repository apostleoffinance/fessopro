# %%
import pandas as pd 
data1 = pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')
data1=data1[2]
data1
# Out:
#                Company Exchange Symbol                        Industry  \
# 0                   3M     NYSE    MMM                    Conglomerate
# 1     American Express     NYSE    AXP              Financial services
# 2                Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3               Amazon   NASDAQ   AMZN                       Retailing
# 4                Apple   NASDAQ   AAPL          Information technology
# 5               Boeing     NYSE     BA           Aerospace and defense
# 6          Caterpillar     NYSE    CAT         Construction and mining
# 7              Chevron     NYSE    CVX              Petroleum industry
# 8                Cisco   NASDAQ   CSCO          Information technology
# 9            Coca-Cola     NYSE     KO                  Drink industry
# 10              Disney     NYSE    DIS  Broadcasting and entertainment
# 11       Goldman Sachs     NYSE     GS              Financial services
# 12          Home Depot     NYSE     HD                Home Improvement
# 13           Honeywell   NASDAQ    HON                    Conglomerate
# 14                 IBM     NYSE    IBM          Information technology
# 15   Johnson & Johnson     NYSE    JNJ         Pharmaceutical industry
# 16      JPMorgan Chase     NYSE    JPM              Financial services
# 17          McDonald's     NYSE    MCD                   Food industry
# 18               Merck     NYSE    MRK         Pharmaceutical industry
# 19           Microsoft   NASDAQ   MSFT          Information technology
# 20                Nike     NYSE    NKE               Clothing industry
# 21              Nvidia   NASDAQ   NVDA          Information technology
# 22    Procter & Gamble     NYSE     PG      Fast-moving consumer goods
# 23          Salesforce     NYSE    CRM          Information technology
# 24    Sherwin-Williams     NYSE    SHW             Specialty chemicals
# 25           Travelers     NYSE    TRV                       Insurance
# 26  UnitedHealth Group     NYSE    UNH             Managed health care
# 27             Verizon     NYSE     VZ     Telecommunications industry
# 28                Visa     NYSE      V              Financial services
# 29             Walmart     NYSE    WMT                       Retailing
#
#     Date added                                  Notes Index weighting
# 0   1976-08-09  As Minnesota Mining and Manufacturing           2.17%
# 1   1982-08-30                                    NaN           4.31%
# 2   2020-08-31                                    NaN           4.14%
# 3   2024-02-26                                    NaN           2.99%
# 4   2015-03-19                                    NaN           2.92%
# 5   1987-03-12                                    NaN           3.03%
# 6   1991-05-06                                    NaN           5.13%
# 7   2008-02-19          Also 1930-07-18 to 1999-11-01           2.01%
# 8   2009-06-08                                    NaN           0.92%
# 9   1987-03-12          Also 1932-05-26 to 1935-11-20           1.04%
# 10  1991-05-06                                    NaN           1.63%
# 11  2013-09-23                                    NaN           8.79%
# 12  1999-11-01                                    NaN           5.35%
# 13  2020-08-31             AlliedSignal and Honeywell           3.27%
# 14  1979-06-29          Also 1932-05-26 to 1939-03-04           3.77%
# 15  1997-03-17                                    NaN           2.24%
# 16  1991-05-06                                    NaN           3.83%
# 17  1985-10-30                                    NaN           4.57%
# 18  1979-06-29                                    NaN           1.11%
# 19  1999-11-01                                    NaN           6.69%
# 20  2013-09-23                                    NaN           0.90%
# 21  2024-11-08                                    NaN           2.02%
# 22  1932-05-26                                    NaN           2.46%
# 23  2020-08-31                                    NaN           3.88%
# 24  2024-11-08                                    NaN           5.19%
# 25  2009-06-08                                    NaN           3.98%
# 26  2012-09-24                                    NaN           4.34%
# 27  2004-04-08                                    NaN           0.63%
# 28  2013-09-23                                    NaN           5.28%
# 29  1997-03-17                                    NaN           1.41%

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          30 non-null     object
#  1   Exchange         30 non-null     object
#  2   Symbol           30 non-null     object
#  3   Industry         30 non-null     object
#  4   Date added       30 non-null     object
#  5   Notes            5 non-null      object
#  6   Index weighting  30 non-null     object
# dtypes: object(7)
# memory usage: 1.8+ KB

# %%
data1['Company'].str.replace(' ', '-')
# Out:
# 0                     3M
# 1       American-Express
# 2                  Amgen
# 3                 Amazon
# 4                  Apple
# 5                 Boeing
# 6            Caterpillar
# 7                Chevron
# 8                  Cisco
# 9              Coca-Cola
# 10                Disney
# 11         Goldman-Sachs
# 12            Home-Depot
# 13             Honeywell
# 14                   IBM
# 15     Johnson-&-Johnson
# 16        JPMorgan-Chase
# 17            McDonald's
# 18                 Merck
# 19             Microsoft
# 20                  Nike
# 21                Nvidia
# 22      Procter-&-Gamble
# 23            Salesforce
# 24      Sherwin-Williams
# 25             Travelers
# 26    UnitedHealth-Group
# 27               Verizon
# 28                  Visa
# 29               Walmart
# Name: Company, dtype: object

# %%
data1['Index weighting'].str.replace('%','')
# Out:
# 0     2.17
# 1     4.31
# 2     4.14
# 3     2.99
# 4     2.92
# 5     3.03
# 6     5.13
# 7     2.01
# 8     0.92
# 9     1.04
# 10    1.63
# 11    8.79
# 12    5.35
# 13    3.27
# 14    3.77
# 15    2.24
# 16    3.83
# 17    4.57
# 18    1.11
# 19    6.69
# 20    0.90
# 21    2.02
# 22    2.46
# 23    3.88
# 24    5.19
# 25    3.98
# 26    4.34
# 27    0.63
# 28    5.28
# 29    1.41
# Name: Index weighting, dtype: object

# %%
list1=[]
for i in data1['Index weighting']:
    list1.append(float(i.replace('%','')))

data1['Index weighting']=list1

# %%
# data1['Index weighting'] = data1['Index weighting'].str.replace('%', '').astype('float')

# %%
data1['Index weighting']
# Out:
# 0     2.17%
# 1     4.31%
# 2     4.14%
# 3     2.99%
# 4     2.92%
# 5     3.03%
# 6     5.13%
# 7     2.01%
# 8     0.92%
# 9     1.04%
# 10    1.63%
# 11    8.79%
# 12    5.35%
# 13    3.27%
# 14    3.77%
# 15    2.24%
# 16    3.83%
# 17    4.57%
# 18    1.11%
# 19    6.69%
# 20    0.90%
# 21    2.02%
# 22    2.46%
# 23    3.88%
# 24    5.19%
# 25    3.98%
# 26    4.34%
# 27    0.63%
# 28    5.28%
# 29    1.41%
# Name: Index weighting, dtype: object

# %%
# data1['Index weighting'] = data1['Index weighting'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data1['Index weighting'] = data1['Index weighting'].astype('int')
#
# File ~/fessopro/fesso-algo/lib/python3.12/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File ~/fessopro/fesso-algo/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/fessopro/fesso-algo/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/fessopro/fesso-algo/lib/python3.12/site-packages/pandas/core/internals/blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~/fessopro/fesso-algo/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/fessopro/fesso-algo/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/fessopro/fesso-algo/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '2.17%'

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          30 non-null     object
#  1   Exchange         30 non-null     object
#  2   Symbol           30 non-null     object
#  3   Industry         30 non-null     object
#  4   Date added       30 non-null     object
#  5   Notes            5 non-null      object
#  6   Index weighting  30 non-null     int64
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB

# %%
data = pd.read_csv('/Users/olaoluwatunmise/fessopro/11_data_analysis/Unicorn_companies.csv')
data
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# 0           Beijing           China           Asia          2012      NaN
# 1         Hawthorne   United States  North America          2002      7.0
# 2          Shenzhen           China           Asia          2008      2.0
# 3     San Francisco   United States  North America          2010      2.0
# 4         Stockholm          Sweden         Europe          2005      4.0
# ...             ...             ...            ...           ...      ...
# 1069       Shanghai           China           Asia          2012    379.0
# 1070        Beijing           China           Asia          2015    990.0
# 1071      Chongqing           China           Asia          2018     80.0
# 1072         London  United Kingdom         Europe          2005    792.0
# 1073     Long Beach   United States  North America          2014    620.0
#
# [1074 rows x 9 columns]

# %%
data = data.fillna(0)
data
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# 0           Beijing           China           Asia          2012      0.0
# 1         Hawthorne   United States  North America          2002      7.0
# 2          Shenzhen           China           Asia          2008      2.0
# 3     San Francisco   United States  North America          2010      2.0
# 4         Stockholm          Sweden         Europe          2005      4.0
# ...             ...             ...            ...           ...      ...
# 1069       Shanghai           China           Asia          2012    379.0
# 1070        Beijing           China           Asia          2015    990.0
# 1071      Chongqing           China           Asia          2018     80.0
# 1072         London  United Kingdom         Europe          2005    792.0
# 1073     Long Beach   United States  North America          2014    620.0
#
# [1074 rows x 9 columns]

# %%
data['Valuation'].std()
# Out:
# np.float64(8.547022216450747)

# %%
data2=pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')
data2=data2[1]
data2
# Out:
#                        Company name      Symbol  \
# 0                 Adani Enterprises    ADANIENT
# 1                 Adani Ports & SEZ  ADANIPORTS
# 2                  Apollo Hospitals  APOLLOHOSP
# 3                      Asian Paints  ASIANPAINT
# 4                         Axis Bank    AXISBANK
# 5                        Bajaj Auto  BAJAJ-AUTO
# 6                     Bajaj Finance  BAJFINANCE
# 7                     Bajaj Finserv  BAJAJFINSV
# 8                Bharat Electronics         BEL
# 9                     Bharti Airtel  BHARTIARTL
# 10                            Cipla       CIPLA
# 11                       Coal India   COALINDIA
# 12         Dr. Reddy's Laboratories     DRREDDY
# 13                    Eicher Motors   EICHERMOT
# 14                          Eternal     ETERNAL
# 15                Grasim Industries      GRASIM
# 16                          HCLTech     HCLTECH
# 17                        HDFC Bank    HDFCBANK
# 18                        HDFC Life    HDFCLIFE
# 19                    Hero MotoCorp  HEROMOTOCO
# 20              Hindalco Industries    HINDALCO
# 21               Hindustan Unilever  HINDUNILVR
# 22                       ICICI Bank   ICICIBANK
# 23                    IndusInd Bank  INDUSINDBK
# 24                          Infosys        INFY
# 25                              ITC         ITC
# 26           Jio Financial Services      JIOFIN
# 27                        JSW Steel    JSWSTEEL
# 28              Kotak Mahindra Bank   KOTAKBANK
# 29                  Larsen & Toubro          LT
# 30              Mahindra & Mahindra         M&M
# 31                    Maruti Suzuki      MARUTI
# 32                     Nestlé India   NESTLEIND
# 33                             NTPC        NTPC
# 34  Oil and Natural Gas Corporation        ONGC
# 35                       Power Grid   POWERGRID
# 36              Reliance Industries    RELIANCE
# 37       SBI Life Insurance Company     SBILIFE
# 38                  Shriram Finance  SHRIRAMFIN
# 39              State Bank of India        SBIN
# 40                       Sun Pharma   SUNPHARMA
# 41        Tata Consultancy Services         TCS
# 42           Tata Consumer Products  TATACONSUM
# 43                      Tata Motors  TATAMOTORS
# 44                       Tata Steel   TATASTEEL
# 45                    Tech Mahindra       TECHM
# 46                    Titan Company       TITAN
# 47                            Trent       TRENT
# 48                 UltraTech Cement  ULTRACEMCO
# 49                            Wipro       WIPRO
#
#                         Sector[15]        Date added[16]
# 0                  Metals & Mining     30 September 2022
# 1                         Services     28 September 2015
# 2                       Healthcare         31 March 2022
# 3                Consumer Durables      27 April 2012[a]
# 4               Financial Services         27 March 2009
# 5   Automobile and Auto Components     1 October 2010[b]
# 6               Financial Services     29 September 2017
# 7               Financial Services          2 April 2018
# 8                    Capital Goods     30 September 2024
# 9                Telecommunication          1 March 2004
# 10                      Healthcare        7 October 1998
# 11     Oil, Gas & Consumable Fuels       10 October 2011
# 12                      Healthcare     1 October 2010[c]
# 13  Automobile and Auto Components          1 April 2016
# 14               Consumer Services         28 March 2025
# 15          Construction Materials       2 April 2018[d]
# 16          Information Technology       28 October 2002
# 17              Financial Services         22 April 1996
# 18              Financial Services          31 July 2020
# 19  Automobile and Auto Components     7 October 1998[e]
# 20                 Metals & Mining         22 April 1996
# 21      Fast Moving Consumer Goods         22 April 1996
# 22              Financial Services       25 January 2002
# 23              Financial Services          1 April 2013
# 24          Information Technology        7 October 1998
# 25      Fast Moving Consumer Goods         22 April 1996
# 26              Financial Services         28 March 2025
# 27                 Metals & Mining     28 September 2018
# 28              Financial Services          8 April 2010
# 29                    Construction   10 December 2004[f]
# 30  Automobile and Auto Components     18 September 1996
# 31  Automobile and Auto Components          1 March 2004
# 32      Fast Moving Consumer Goods  27 September 2019[g]
# 33                           Power     24 September 2007
# 34     Oil, Gas & Consumable Fuels         12 April 2004
# 35                           Power         14 March 2008
# 36     Oil, Gas & Consumable Fuels         22 April 1996
# 37              Financial Services     25 September 2020
# 38              Financial Services         28 March 2024
# 39              Financial Services         22 April 1996
# 40                      Healthcare       17 January 2002
# 41          Information Technology      25 February 2005
# 42      Fast Moving Consumer Goods      31 March 2021[h]
# 43  Automobile and Auto Components         22 April 1996
# 44                 Metals & Mining         22 April 1996
# 45          Information Technology         28 March 2014
# 46               Consumer Durables          2 April 2018
# 47               Consumer Services     30 September 2024
# 48          Construction Materials     28 September 2012
# 49          Information Technology  27 September 2013[i]

# %%
for i in data2['Date added[16]']:
    print(i)
# Out:
# 30 September 2022
# 28 September 2015
# 31 March 2022
# 27 April 2012[a]
# 27 March 2009
# 1 October 2010[b]
# 29 September 2017
# 2 April 2018
# 30 September 2024
# 1 March 2004
# 7 October 1998
# 10 October 2011
# 1 October 2010[c]
# 1 April 2016
# 28 March 2025
# 2 April 2018[d]
# 28 October 2002
# 22 April 1996
# 31 July 2020
# 7 October 1998[e]
# 22 April 1996
# 22 April 1996
# 25 January 2002
# 1 April 2013
# 7 October 1998
# 22 April 1996
# 28 March 2025
# 28 September 2018
# 8 April 2010
# 10 December 2004[f]
# 18 September 1996
# 1 March 2004
# 27 September 2019[g]
# 24 September 2007
# 12 April 2004
# 14 March 2008
# 22 April 1996
# 25 September 2020
# 28 March 2024
# 22 April 1996
# 17 January 2002
# 25 February 2005
# 31 March 2021[h]
# 22 April 1996
# 22 April 1996
# 28 March 2014
# 2 April 2018
# 30 September 2024
# 28 September 2012
# 27 September 2013[i]

# %%
list2=[]
for i in data2['Date added[16]']:
    if i[-3]=='[':
        list2.append(i[:-3])
    else:
        list2.append(i)

data2['Date added[16]'] = list2
data2
# Out:
#                        Company name      Symbol  \
# 0                 Adani Enterprises    ADANIENT
# 1                 Adani Ports & SEZ  ADANIPORTS
# 2                  Apollo Hospitals  APOLLOHOSP
# 3                      Asian Paints  ASIANPAINT
# 4                         Axis Bank    AXISBANK
# 5                        Bajaj Auto  BAJAJ-AUTO
# 6                     Bajaj Finance  BAJFINANCE
# 7                     Bajaj Finserv  BAJAJFINSV
# 8                Bharat Electronics         BEL
# 9                     Bharti Airtel  BHARTIARTL
# 10                            Cipla       CIPLA
# 11                       Coal India   COALINDIA
# 12         Dr. Reddy's Laboratories     DRREDDY
# 13                    Eicher Motors   EICHERMOT
# 14                          Eternal     ETERNAL
# 15                Grasim Industries      GRASIM
# 16                          HCLTech     HCLTECH
# 17                        HDFC Bank    HDFCBANK
# 18                        HDFC Life    HDFCLIFE
# 19                    Hero MotoCorp  HEROMOTOCO
# 20              Hindalco Industries    HINDALCO
# 21               Hindustan Unilever  HINDUNILVR
# 22                       ICICI Bank   ICICIBANK
# 23                    IndusInd Bank  INDUSINDBK
# 24                          Infosys        INFY
# 25                              ITC         ITC
# 26           Jio Financial Services      JIOFIN
# 27                        JSW Steel    JSWSTEEL
# 28              Kotak Mahindra Bank   KOTAKBANK
# 29                  Larsen & Toubro          LT
# 30              Mahindra & Mahindra         M&M
# 31                    Maruti Suzuki      MARUTI
# 32                     Nestlé India   NESTLEIND
# 33                             NTPC        NTPC
# 34  Oil and Natural Gas Corporation        ONGC
# 35                       Power Grid   POWERGRID
# 36              Reliance Industries    RELIANCE
# 37       SBI Life Insurance Company     SBILIFE
# 38                  Shriram Finance  SHRIRAMFIN
# 39              State Bank of India        SBIN
# 40                       Sun Pharma   SUNPHARMA
# 41        Tata Consultancy Services         TCS
# 42           Tata Consumer Products  TATACONSUM
# 43                      Tata Motors  TATAMOTORS
# 44                       Tata Steel   TATASTEEL
# 45                    Tech Mahindra       TECHM
# 46                    Titan Company       TITAN
# 47                            Trent       TRENT
# 48                 UltraTech Cement  ULTRACEMCO
# 49                            Wipro       WIPRO
#
#                         Sector[15]     Date added[16]
# 0                  Metals & Mining  30 September 2022
# 1                         Services  28 September 2015
# 2                       Healthcare      31 March 2022
# 3                Consumer Durables      27 April 2012
# 4               Financial Services      27 March 2009
# 5   Automobile and Auto Components     1 October 2010
# 6               Financial Services  29 September 2017
# 7               Financial Services       2 April 2018
# 8                    Capital Goods  30 September 2024
# 9                Telecommunication       1 March 2004
# 10                      Healthcare     7 October 1998
# 11     Oil, Gas & Consumable Fuels    10 October 2011
# 12                      Healthcare     1 October 2010
# 13  Automobile and Auto Components       1 April 2016
# 14               Consumer Services      28 March 2025
# 15          Construction Materials       2 April 2018
# 16          Information Technology    28 October 2002
# 17              Financial Services      22 April 1996
# 18              Financial Services       31 July 2020
# 19  Automobile and Auto Components     7 October 1998
# 20                 Metals & Mining      22 April 1996
# 21      Fast Moving Consumer Goods      22 April 1996
# 22              Financial Services    25 January 2002
# 23              Financial Services       1 April 2013
# 24          Information Technology     7 October 1998
# 25      Fast Moving Consumer Goods      22 April 1996
# 26              Financial Services      28 March 2025
# 27                 Metals & Mining  28 September 2018
# 28              Financial Services       8 April 2010
# 29                    Construction   10 December 2004
# 30  Automobile and Auto Components  18 September 1996
# 31  Automobile and Auto Components       1 March 2004
# 32      Fast Moving Consumer Goods  27 September 2019
# 33                           Power  24 September 2007
# 34     Oil, Gas & Consumable Fuels      12 April 2004
# 35                           Power      14 March 2008
# 36     Oil, Gas & Consumable Fuels      22 April 1996
# 37              Financial Services  25 September 2020
# 38              Financial Services      28 March 2024
# 39              Financial Services      22 April 1996
# 40                      Healthcare    17 January 2002
# 41          Information Technology   25 February 2005
# 42      Fast Moving Consumer Goods      31 March 2021
# 43  Automobile and Auto Components      22 April 1996
# 44                 Metals & Mining      22 April 1996
# 45          Information Technology      28 March 2014
# 46               Consumer Durables       2 April 2018
# 47               Consumer Services  30 September 2024
# 48          Construction Materials  28 September 2012
# 49          Information Technology  27 September 2013
