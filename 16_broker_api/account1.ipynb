# %%
from alpaca.trading.client import TradingClient
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Fetch keys from environment
api_key = os.getenv("API_KEY")
secret_key = os.getenv("SECRET_KEY")

# Connect to Alpaca (set paper=True for paper trading, paper=False for live crypto trading)
trading_client = TradingClient(api_key, secret_key, paper=True)

# Get account details
account = trading_client.get_account()
print(account)
# Out:
# id=UUID('e0c394a4-e5f6-4df8-b51d-6e5f8f670ae1') account_number='PA337CM3CLW9' status=<AccountStatus.ACTIVE: 'ACTIVE'> crypto_status=<AccountStatus.ACTIVE: 'ACTIVE'> currency='USD' buying_power='199587.96' regt_buying_power='199587.96' daytrading_buying_power='0' non_marginable_buying_power='99793.98' cash='99793.98' accrued_fees='0' pending_transfer_out=None pending_transfer_in=None portfolio_value='100108.99' pattern_day_trader=False trading_blocked=False transfers_blocked=False account_blocked=False created_at=datetime.datetime(2024, 11, 14, 16, 14, 45, 303574, tzinfo=TzInfo(UTC)) trade_suspended_by_user=False multiplier='2' shorting_enabled=True equity='100108.99' last_equity='100101.649352865' long_market_value='315.01' short_market_value='0' initial_margin='0' maintenance_margin='0' last_maintenance_margin='0' sma='99793.98' daytrade_count=0 options_buying_power='99793.98' options_approved_level=3 options_trading_level=3

# %%
account.equity
# Out:
# '100108.99'

# %%
import pandas as pd
df=pd.Series(dict(account))
df.to_csv('data.csv')

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest
from alpaca.trading.enums import AssetClass

trading_client = TradingClient(api_key, secret_key)

# search for crypto assets
#search_params = GetAssetsRequest(asset_class=AssetClass.CRYPTO)

search_params = GetAssetsRequest(asset_class=AssetClass.US_EQUITY)

assets = trading_client.get_all_assets(search_params)

# %%
assets
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('4098584d-cab8-498d-bc99-f6f1a9d2c86c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Eden Research plc Ordinary Shares (United Kingdom)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'EDNSF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('b03182e5-d2e5-40b3-9287-13395ec7b08c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'CYPRESS ENVIRONMENTAL PARTNERS L P Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'CELPQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8db9459b-f0c2-4f92-8cd2-29e8e21497f9'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'AYALA CORP ADR - Unsponsored (Philippines)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'AYALY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('906a5ea5-8da1-48cb-9037-7e74f66c8a88'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Uniroyal Global Engineered Products, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'UNIR',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('9dca91ac-bb60-4096-a038-168d4efbb0de'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Aether Catalyst Solutions Inc Common Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'ATHHF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a05fbadd-3a0c-4c89-9b5e-7750a4bb1113'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'SIGMATA ELECTRONICS INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'SMGE',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f48badef-67bd-40dd-ae74-304fce86c588'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Banks IS Gold Ltd Ordinary Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'BKSLF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('25113791-0a75-481f-9bd8-8080c25c6ea7'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Golden Eagle Retail Group Ltd Ordinary Shares (Cayman Islands)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GDNEF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('09e76606-73d5-4232-9572-e286708f9c63'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'RegalWorks Media, Inc Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'RWMI',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('c778657f-41c6-4650-985c-b48b6b4c511b'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Superior Marktng Research Crp Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'SMRH',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('c1bbc3a4-d218-4be1-8fb6-08d3bcc0bb02'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Charter Hall Long Wale Reit Fully Paid Units Stapled Securities '
#              '(Australia)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'CHLWF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a5f90393-f716-4773-b1eb-4c101e5439d5'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Hero International USA Holding Corp Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'HIUH',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3bd11031-7bdb-4e21-b87f-da29c6d6b548'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Oasis Petroleum Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'OASPQ',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID

#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('32ea8235-cf1f-41e2-bfef-ee60870d8196'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'RSE ARCHIVE LLC MEMBERSHIP INT SER - 1936 JESSE OWENS OLYMPICS',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'RARWS',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f1a63b0a-1045-406f-8d40-665012ad99ff'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Coronation Fund Managers Ltd Ordinary Shares (South Africa)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'COFUF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3f82dbd4-4441-446c-9685-29bd25409eca'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'PILLAR CORP COM STK (Japan)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'NLLRF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('bbc9a04b-974d-4ab3-a866-2243170c4d09'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GRAYSCALE STELLAR LUMENS TR XLM COM UNIT Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GXLM',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('3e44231e-3e72-47b5-b3f2-5b0efb45859e'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Whitbread PLC American Depositary Receipts - Sponsored (United '
#              'Kingdom)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'WTBDY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8e283a80-1d41-44af-8b08-34b9920f9cd2'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Vivendi SE American Depositary Receipts - Unsponsored',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'VIVHY',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('2a52c1aa-0b1d-432e-8aa7-e1e64fb395bf'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GENERIC GOLD CORP Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GGCPF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('620451b1-ce4b-4d56-902b-55dc26477acf'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Gaztransport & Tecnigaz American Depository Receipt (France)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GZPZY',
#      'tradable': False},
#  ...]

# %%
list1=[]

for i in assets:
    list1.append(dict(i))
df=pd.DataFrame(list1)
#df.to_csv('assets.csv')
df
# Out:
#                                          id           asset_class  \
# 0      4098584d-cab8-498d-bc99-f6f1a9d2c86c  AssetClass.US_EQUITY
# 1      b03182e5-d2e5-40b3-9287-13395ec7b08c  AssetClass.US_EQUITY
# 2      8db9459b-f0c2-4f92-8cd2-29e8e21497f9  AssetClass.US_EQUITY
# 3      906a5ea5-8da1-48cb-9037-7e74f66c8a88  AssetClass.US_EQUITY
# 4      9dca91ac-bb60-4096-a038-168d4efbb0de  AssetClass.US_EQUITY
# ...                                     ...                   ...
# 32117  451b94f4-1710-4f79-8e77-583148f71bee  AssetClass.US_EQUITY
# 32118  cd1347d7-8add-49bd-acd1-4ffde9a4081b  AssetClass.US_EQUITY
# 32119  0cf42aa3-9816-4f1f-aa84-6482ac9303e9  AssetClass.US_EQUITY
# 32120  cc7823b0-3e75-4ce2-9dab-4ec9115a512f  AssetClass.US_EQUITY
# 32121  c9081ff9-27ac-4c1b-a8a4-37082278d501  AssetClass.US_EQUITY
#
#                    exchange symbol  \
# 0         AssetExchange.OTC  EDNSF
# 1         AssetExchange.OTC  CELPQ
# 2         AssetExchange.OTC  AYALY
# 3         AssetExchange.OTC   UNIR
# 4         AssetExchange.OTC  ATHHF
# ...                     ...    ...
# 32117  AssetExchange.NASDAQ   BSAA
# 32118  AssetExchange.NASDAQ   INTU
# 32119  AssetExchange.NASDAQ   INTC
# 32120    AssetExchange.ARCA    EPP
# 32121    AssetExchange.ARCA   DCOR
#
#                                                     name  \
# 0      Eden Research plc Ordinary Shares (United King...
# 1        CYPRESS ENVIRONMENTAL PARTNERS L P Common Stock
# 2             AYALA CORP ADR - Unsponsored (Philippines)
# 3      Uniroyal Global Engineered Products, Inc. Comm...
# 4      Aether Catalyst Solutions Inc Common Shares (C...
# ...                                                  ...
# 32117  BEST SPAC I Acquisition Corp. Class A Ordinary...
# 32118                           Intuit Inc. Common Stock
# 32119                     Intel Corporation Common Stock
# 32120                  iShares MSCI Pacific ex Japan ETF
# 32121                   Dimensional US Core Equity 1 ETF
#
#                      status  tradable  marginable  shortable  easy_to_borrow  \
# 0      AssetStatus.INACTIVE     False       False      False           False
# 1      AssetStatus.INACTIVE     False       False      False           False
# 2      AssetStatus.INACTIVE     False       False      False           False
# 3      AssetStatus.INACTIVE     False       False      False           False
# 4      AssetStatus.INACTIVE     False       False      False           False
# ...                     ...       ...         ...        ...             ...
# 32117    AssetStatus.ACTIVE      True        True      False           False
# 32118    AssetStatus.ACTIVE      True        True       True            True
# 32119    AssetStatus.ACTIVE      True        True       True            True
# 32120    AssetStatus.ACTIVE      True        True       True            True
# 32121    AssetStatus.ACTIVE      True        True      False           False
#
#        fractionable min_order_size min_trade_increment price_increment  \
# 0             False           None                None            None
# 1             False           None                None            None
# 2             False           None                None            None
# 3             False           None                None            None
# 4             False           None                None            None
# ...             ...            ...                 ...             ...
# 32117         False           None                None            None
# 32118          True           None                None            None
# 32119          True           None                None            None
# 32120          True           None                None            None
# 32121          True           None                None            None
#
#        maintenance_margin_requirement                            attributes
# 0                               100.0                                    []
# 1                               100.0                                    []
# 2                               100.0                                    []
# 3                               100.0                                    []
# 4                               100.0                                    []
# ...                               ...                                   ...
# 32117                            30.0                                    []
# 32118                            30.0  [fractional_eh_enabled, has_options]
# 32119                            30.0  [fractional_eh_enabled, has_options]
# 32120                            30.0  [fractional_eh_enabled, has_options]
# 32121                            30.0  [fractional_eh_enabled, has_options]
#
# [32122 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32122 entries, 0 to 32121
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              32122 non-null  object
#  1   asset_class                     32122 non-null  object
#  2   exchange                        32122 non-null  object
#  3   symbol                          32122 non-null  object
#  4   name                            32122 non-null  object
#  5   status                          32122 non-null  object
#  6   tradable                        32122 non-null  bool
#  7   marginable                      32122 non-null  bool
#  8   shortable                       32122 non-null  bool
#  9   easy_to_borrow                  32122 non-null  bool
#  10  fractionable                    32122 non-null  bool
#  11  min_order_size                  0 non-null      object
#  12  min_trade_increment             0 non-null      object
#  13  price_increment                 0 non-null      object
#  14  maintenance_margin_requirement  32122 non-null  float64
#  15  attributes                      32122 non-null  object
# dtypes: bool(5), float64(1), object(10)
# memory usage: 2.8+ MB

# %%
df[df['shortable']==True]['symbol'].to_list()
# Out:
# ['ASAIY',
#  'NSANY',
#  'LOGC',
#  'DTRUY',
#  'MBGAF',
#  'CKHUY',
#  'TOP',
#  'ABBNY',
#  'WCPRF',
#  'CAJPY',
#  'INSW',
#  'INSM',
#  'INOD',
#  'INMD',
#  'INFY',
#  'INDY',
#  'INDI',
#  'INDA',
#  'INCY',
#  'IMVT',
#  'HFXI',
#  'ILMN',
#  'FRDM',
#  'ILF',
#  'IJR',
#  'IJH',
#  'IIPR',
#  'IHI',
#  'IHDG',
#  'IGV',
#  'IGSB',
#  'IGPT',
#  'IGOV',
#  'FMB',
#  'IGLB',
#  'IGIB',
#  'IFRA',
#  'IFF',
#  'IEX',
#  'IEV',
#  'IEUR',
#  'IESC',
#  'IEMG',
#  'IEI',
#  'IEFA',
#  'IEF',
#  'FLBL',
#  'IDXX',
#  'IDV',
#  'IDEV',
#  'ETHE',
#  'ICSH',
#  'ICLN',
#  'ICE',
#  'IBTM',
#  'IBTF',
#  'IBN',
#  'IBM',
#  'IBKR',
#  'IBIT',
#  'IBHF',
#  'IBDX',
#  'IBDW',
#  'ESML',
#  'IBDT',
#  'BWX',
#  'BSCT',
#  'IBDS',
#  'IBDQ',
#  'IBB',
#  'IAU',
#  'BSCQ',
#  'IAS',
#  'HYS',
#  'HYLB',
#  'BILZ',
#  'AIA',
#  'EZET',
#  'HYG',
#  'GRMN',
#  'HYEM',
#  'ONTO',
#  'ONON',
#  'ONEQ',
#  'ON',
#  'OMF',
#  'S',
#  'MNDY',
#  'LTC',
#  'KVYO',
#  'KNSL',
#  'JNJ',
#  'ICLO',
#  'PULS',
#  'NYF',
#  'MAS',
#  'KVUE',
#  'NI',
#  'MMM',
#  'PODD',
#  'JANX',
#  'ICVT',
#  'MLM',
#  'SYF',
#  'PPL',
#  'K',
#  'SPGI',
#  'KRMN',
#  'ROL',
#  'SYY',
#  'RTX',
#  'PFE',
#  'IREN',
#  'T',
#  'SRE',
#  'PLTY',
#  'PATH',
#  'FTNT',
#  'PAAA',
#  'NWS',
#  'MTD',
#  'MPLX',
#  'JKHY',
#  'IYR',
#  'IPG',
#  'ITB',
#  'LII',
#  'OMC',
#  'PSTG',
#  'NXE',
#  'LUV',
#  'CE',
#  'IRM',
#  'SJM',
#  'RING',
#  'RAL',
#  'PM',
#  'MOAT',
#  'JMBS',
#  'IWD',
#  'IGF',
#  'IBDU',
#  'IBDR',
#  'JCPB',
#  'IGRO',
#  'SLM',
#  'RGLD',
#  'QLTA',
#  'POWL',
#  'PKX',
#  'NLY.PRJ',
#  'AZO',
#  'NFRA',
#  'MOO',
#  'ACWI',
#  'MMYT',
#  'LGOV',
#  'CVNA',
#  'KSA',
#  'IWO',
#  'BND',
#  'IMTM',
#  'BA',
#  'DVN',
#  'COTY',
#  'IEO',
#  'BIDU',
#  'IDU',
#  'IBTJ',
#  'IBTG',
#  'IBND',
#  'HYLS',
#  'BSCX',
#  'SVXY',
#  'CAMT',
#  'SONO',
#  'ERJ',
#  'SEIX',
#  'SDIV',
#  'SCHD',
#  'ROM',
#  'RKLX',
#  'REK',
#  'AMZN',
#  'EETH',
#  'PSQH',
#  'NVO',
#  'BAR',
#  'MUNI',
#  'MTBA',
#  'MCHI',
#  'LABX',
#  'KOMP',
#  'JPLD',
#  'JGLO',
#  'IXJ',
#  'ISTB',
#  'HYTR',
#  'M',
#  'IAUM',
#  'QXO',
#  'PBF',
#  'ASAN',
#  'MA',
#  'LLY',
#  'PVH',
#  'NVR',
#  'SMA',
#  'OGN',
#  'JPM',
#  'ORCL',
#  'KO',
#  'IWV',
#  'SHNY',
#  'RBRK',
#  'RDDT',
#  'PSA',
#  'PD',
#  'LOW',
#  'ADSK',
#  'L',
#  'STE',
#  'QTUM',
#  'CSQ',
#  'HLT',
#  'ETHV',
#  'ECL',
#  'CTAS',
#  'COR',
#  'CMG',
#  'BROS',
#  'AOK',
#  'ACGL',
#  'ADT',
#  'GVAL',
#  'DFAE',
#  'GCT',
#  'DOCS',
#  'CVX',
#  'CDE',
#  'GNL',
#  'CVI',
#  'COPX',
#  'BRKR',
#  'AME',
#  'EMLP',
#  'FPE',
#  'HYDB',
#  'ITOCY',
#  'HWM',
#  'HUT',
#  'HUM',
#  'HUBS',
#  'HTZ',
#  'HTGC',
#  'HSY',
#  'HST',
#  'HRL',
#  'HPQ',
#  'HPE',
#  'HP',
#  'HOOY',
#  'HOOD',
#  'HON',
#  'HOLX',
#  'HOG',
#  'HODL',
#  'HMY',
#  'HLX',
#  'HIMX',
#  'HIMS',
#  'HII',
#  'ECBK',
#  'HIG',
#  'HHH',
#  'HEFA',
#  'HEDJ',
#  'HE',
#  'HDV',
#  'HDB',
#  'HD',
#  'HCC',
#  'HCA',
#  'HBM',
#  'HBAN',
#  'HASI',
#  'HAS',
#  'H',
#  'GWW',
#  'GUSH',
#  'GUNR',
#  'GTO',
#  'GTM',
#  'GTLB',
#  'GT',
#  'KG',
#  'GSY',
#  'GSST',
#  'GSK',
#  'GSIE',
#  'GSG',
#  'GSBD',
#  'GS',
#  'GRNY',
#  'PBUS',
#  'GRND',
#  'GREK',
#  'GRAL',
#  'GPN',
#  'GPCR',
#  'GOVZ',
#  'GOVT',
#  'GOOY',
#  'GOOS',
#  'GOOGL',
#  'GOOG',
#  'SGI',
#  'GNRC',
#  'GNR',
#  'GME',
#  'GLXY',
#  'GLOB',
#  'GLDM',
#  'AVES',
#  'GLD',
#  'GLBE',
#  'GL',
#  'GIS',
#  'GILD',
#  'GIGB',
#  'GH',
#  'GFS',
#  'GFI',
#  'GEV',
#  'GEO',
#  'GENI',
#  'GEN',
#  'GEM',
#  'GEHC',
#  'GE',
#  'GDXJ',
#  'GDX',
#  'GDS',
#  'GDDY',
#  'GD',
#  'GBTC',
#  'GBIL',
#  'GAP',
#  'FXI',
#  'FVRR',
#  'FUTU',
#  'FUN',
#  'FTSL',
#  'FTEC',
#  'FTAI',
#  'FSLY',
#  'FSK',
#  'FRT',
#  'FRSH',
#  'FRPT',
#  'FROG',
#  'FOXA',
#  'FOX',
#  'FOUR',
#  'FNV',
#  'FNGS',
#  'FNDF',
#  'FNDE',
#  'FMC',
#  'FLTR',
#  'FLRT',
#  'FLRN',
#  'FLR',
#  'FLOT',
#  'FLO',
#  'FLNC',
#  'FLKR',
#  'FLJP',
#  'FLIN',
#  'FLGB',
#  'FLG',
#  'FLEX',
#  'FL',
#  'FIXD',
#  'FIX',
#  'FIVN',
#  'FIVE',
#  'FITB',
#  'FIS',
#  'FICO',
#  'FI',
#  'FFIV',
#  'FEPI',
#  'FDN',
#  'FDMT',
#  'FCX',
#  'FCNCA',
#  'FBND',
#  'FBCG',
#  'FAST',
#  'FAS',
#  'FANG',
#  'FALN',
#  'F',
#  'EZU',
#  'EXTR',
#  'EXR',
#  'EXPI',
#  'EXPE',
#  'EXPD',
#  'EXEL',
#  'EXE',
#  'EXC',
#  'EXAS',
#  'EWY',
#  'EWW',
#  'EWU',
#  'EWTX',
#  'EWS',
#  'EWM',
#  'EWL',
#  'EWJV',
#  'EWJ',
#  'EWG',
#  'EWC',
#  'EWA',
#  'EW',
#  'EVRG',
#  'ETSY',
#  'ETR',
#  'ETOR',
#  'ETN',
#  'ETHU',
#  'ETHT',
#  'ETHA',
#  'ETH',
#  'ET',
#  'ESTC',
#  'ESLT',
#  'ESGU',
#  'ESGE',
#  'ESGD',
#  'ES',
#  'ERIE',
#  'EQR',
#  'EQIX',
#  'CPNG',
#  'EPR',
#  'GCC',
#  'EPI',
#  'EPD',
#  'EPAM',
#  'EOG',
#  'ENVX',
#  'ENPH',
#  'INUV',
#  'ENB',
#  'EMXC',
#  'EMN',
#  'EMLC',
#  'EME',
#  'EMB',
#  'ELV',
#  'ELF',
#  'EL',
#  'EIX',
#  'EG',
#  'EFX',
#  'EFV',
#  'EFG',
#  'EFC',
#  'EFAV',
#  'EFA',
#  'EEMV',
#  'EEM',
#  'EDV',
#  'EDU',
#  'ED',
#  'COUR',
#  'EBAY',
#  'EAGG',
#  'EA',
#  'DYN',
#  'DXJ',
#  'EIC',
#  'DXCM',
#  'DXC',
#  'DX',
#  'DVYE',
#  'HHS',
#  'DVY',
#  'TBMC',
#  'DVAX',
#  'DV',
#  'DUOL',
#  'DTE',
#  'DTCR',
#  'DSI',
#  'MVV',
#  'DRS',
#  'VTEX',
#  'DRI',
#  'DRD',
#  'DQ',
#  'DPZ',
#  'DPST',
#  'DOW',
#  'DOV',
#  'DOCU',
#  'DOCN',
#  'DOC',
#  'DNUT',
#  'DLTR',
#  'DLR',
#  'DLO',
#  'DKS',
#  'DKNG',
#  'DJT',
#  'DIVO',
#  'DISV',
#  'DIS',
#  'DINO',
#  'DIA',
#  'DHT',
#  'DHR',
#  'DHI',
#  'DGS',
#  'DGRW',
#  'DGRO',
#  'DG',
#  'DFNM',
#  'DFIV',
#  'DFIC',
#  'DFEV',
#  'DFAX',
#  'DFAI',
#  'DFAC',
#  'DEO',
#  'DEM',
#  'DELL',
#  'DECK',
#  'DEA',
#  'DE',
#  'DDOG',
#  'DD',
#  'DBX',
#  'DBRG',
#  'DBEF',
#  'DBC',
#  'DBA',
#  'DAY',
#  'DAX',
#  'DAVE',
#  'DAVA',
#  'DASH',
#  'DAL',
#  'D',
#  'CZR',
#  'CYTK',
#  'CYBR',
#  'CXW',
#  'CXM',
#  'CWH',
#  'CWEN',
#  'CVE',
#  'CURE',
#  'CUK',
#  'CUBE',
#  'CTVA',
#  'CTSH',
#  'CTRA',
#  'CSX',
#  'CSWC',
#  'CSGP',
#  'CSCO',
#  'CRWD',
#  'CRSR',
#  'CRS',
#  'CROX',
#  'CRL',
#  'CRK',
#  'CRGY',
#  'CRDO',
#  'CQQQ',
#  'CPT',
#  'CPRX',
#  'CPRT',
#  'CPRI',
#  'CPER',
#  'CPB',
#  'CPAY',
#  'CP',
#  'COWZ',
#  'COST',
#  'CORT',
#  'COOP',
#  'COO',
#  'COKE',
#  'COIN',
#  'COHR',
#  'COCO',
#  'CNXC',
#  'CNR',
#  'CNQ',
#  'CNP',
#  'DBO',
#  'CNH',
#  'CMS',
#  'CMPO',
#  'CMI',
#  'CMF',
#  'CME',
#  'CMCSA',
#  'CLX',
#  'CLSK',
#  'CLS',
#  'CLOZ',
#  'CLOI',
#  'CLIP',
#  'ECNS',
#  'CLF',
#  'CLBT',
#  'CL',
#  'CIVI',
#  'CINF',
#  'CIEN',
#  'CIBR',
#  'JMST',
#  'MCR',
#  'CHWY',
#  'CHTR',
#  'CHRW',
#  'CHRD',
#  'CHD',
#  'CHAU',
#  'CGGR',
#  'CFLT',
#  'CFG',
#  'RMD',
#  'CENX',
#  'CELH',
#  'SITE',
#  'CEG',
#  'CDTX',
#  'CDNS',
#  'CCL',
#  'CCJ',
#  'CCEP',
#  'CC',
#  'CBRE',
#  'CBOE',
#  'CB',
#  'CAVA',
#  'CAT',
#  'CASY',
#  'CART',
#  'CARR',
#  'CAR',
#  'CALM',
#  'CAKE',
#  'CAH',
#  'CAG',
#  'C',
#  'BYON',
#  'BXSL',
#  'BXMT',
#  'BX',
#  'ATH.PRA',
#  'BUXX',
#  'BUG',
#  'BUD',
#  'BTU',
#  'BTI',
#  'BTFX',
#  'BTDR',
#  'BSRR',
#  'BTCO',
#  'BSV',
#  'BSM',
#  'BSCU',
#  'BSCS',
#  'BSCR',
#  'BRZE',
#  'BRO',
#  'BRK.B',
#  'BR',
#  'BOXX',
#  'BOTZ',
#  'BORR',
#  'PDP',
#  'BOIL',
#  'BNTX',
#  'BNS',
#  'BNDX',
#  'BNDW',
#  'BN',
#  'RPG',
#  'RWJ',
#  'TDIV',
#  'BMY',
#  'BMRN',
#  'BMBL',
#  'BLV',
#  'BLOK',
#  'BLK',
#  'BLDR',
#  'BLBD',
#  'BKR',
#  'BKNG',
#  'BKLN',
#  'BKLC',
#  'BK',
#  'BJ',
#  'BIV',
#  'BITX',
#  'BITQ',
#  'BINC',
#  'XONE',
#  'BILS',
#  'BILL',
#  'BILI',
#  'BIL',
#  'BIIB',
#  'BG',
#  'BEPC',
#  'BEN',
#  'BEKE',
#  'BEAM',
#  'BE',
#  'BDX',
#  'BCS',
#  'BCRX',
#  'BBWI',
#  'BBIO',
#  'BBHY',
#  'BBEU',
#  'BBAR',
#  'BAX',
#  'BANC',
#  'BAC',
#  'BABX',
#  'BABA',
#  'BAB',
#  'B',
#  'AZN',
#  'AXSM',
#  'AXP',
#  'AXON',
#  'AWK',
#  'AVY',
#  'AVUV',
#  'AVPT',
#  'AVL',
#  'AVGO',
#  'AVEM',
#  'AVDV',
#  'AVDE',
#  'AVB',
#  'AVAV',
#  'AUPH',
#  'ATKR',
#  'ATEC',
#  'NBN',
#  'BJRI',
#  'ASX',
#  'ASTS',
#  'ASPN',
#  'ASO',
#  'ASML',
#  'ASHR',
#  'AL',
#  'ARTY',
#  'ARRY',
#  'ARR',
#  'ARQT',
#  'ARMK',
#  'ARM',
#  'ARLP',
#  'ARLO',
#  'ARKX',
#  'ARKW',
#  'ARKQ',
#  'ARKF',
#  'ARIS',
#  'ARI',
#  'ARGT',
#  'ARE',
#  'BKAG',
#  'ARCO',
#  'ARCC',
#  'AR',
#  'AQN',
#  'CDW',
#  'CHGG',
#  'APTV',
#  'APPN',
#  'APP',
#  'APO',
#  'APLY',
#  'APLS',
#  'APLE',
#  'COLL',
#  'APLD',
#  'APH',
#  'APD',
#  'APA',
#  'AOS',
#  'AOR',
#  'AON',
#  'AOM',
#  'AOA',
#  'ANGL',
#  'ANF',
#  'ANET',
#  'AMZY',
#  'AMZU',
#  'AMTM',
#  'AMT',
#  'DNN',
#  'AMSC',
#  'EDAP',
#  'AMR',
#  'AMP',
#  'AMKR',
#  'AMGN',
#  'AMDY',
#  'AMDL',
#  'AMD',
#  'AMCR',
#  'AMC',
#  'AMBA',
#  'AMAT',
#  'EZBC',
#  'AM',
#  'ALLY',
#  'ALLE',
#  'FEZ',
#  'ALL',
#  'ALK',
#  'ALHC',
#  'ALGN',
#  'JPIE',
#  'FSTR',
#  'VBF',
#  'ALGM',
#  'VLGEA',
#  'ALB',
#  'UDR',
#  'ALAB',
#  'BIZD',
#  'AKRO',
#  'AKAM',
#  'ESGV',
#  'AJG',
#  'GLW',
#  'OKE',
#  'AIZ',
#  'PCAR',
#  'TNET',
#  'WWJD',
#  'AIYY',
#  'AIQ',
#  'AIPI',
#  'AIG',
#  'IMO',
#  'AI',
#  'JBL',
#  'AHR',
#  'AGX',
#  'AGQ',
#  'LMB',
#  'SIEGY',
#  'RHHBY',
#  'FIW',
#  'FINW',
#  'KCE',
#  'WRLD',
#  'KTCC',
#  'VFVA',
#  'XMVM',
#  'RCG',
#  'FVR',
#  'MG',
#  'SEE',
#  'SMP',
#  'VUSB',
#  'SSREY',
#  'DTEGY',
#  'KRYAY',
#  'FJTSY',
#  'ZURVY',
#  'PNGAY',
#  'SINGY',
#  'PROSY',
#  'NSRGY',
#  'CHGCY',
#  'NTDOY',
#  'DBSDY',
#  'MIELY',
#  'BRDCY',
#  'FUJIY',
#  'KDDIY',
#  'DHLGY',
#  'CFRUY',
#  'BAESY',
#  'TKOMY',
#  'LKNCY',
#  'SGBLY',
#  'SFTBY',
#  'TCEHY',
#  'NPSNY',
#  'IMBBY',
#  'BGR',
#  'EOS',
#  'SOTK',
#  'SF',
#  'URG',
#  'HYIN',
#  'GIFI',
#  'ACP',
#  'JOF',
#  'SR',
#  'TDF',
#  'ANRO',
#  'IXC',
#  'MLNK',
#  'TPG',
#  'DDS',
#  'HPF',
#  'LEN.B',
#  'BLND',
#  'ACA',
#  'ANNX',
#  'LOAR',
#  'NCDL',
#  'PRLB',
#  'SHCO',
#  'AFBI',
#  'BHFAN',
#  'BPYPO',
#  'CIM.PRB',
#  'FXH',
#  'FXR',
#  'NSTS',
#  'PBHC',
#  'PROV',
#  'SHBI',
#  'TFC.PRR',
#  'INDF',
#  'GPOR',
#  'PAMT',
#  'NPB',
#  'BF.A',
#  'GNK',
#  'TECK',
#  'BKV',
#  'PJT',
#  'JOE',
#  'AGNC',
#  'CTBB',
#  'MDST',
#  'ZDEK',
#  'CCMG',
#  'OMER',
#  'AAUC',
#  'AHT',
#  'ASHS',
#  'ASMB',
#  'AVTX',
#  'BAC.PRL',
#  'BAC.PRO',
#  'BAI',
#  'BANX',
#  'BCBP',
#  'BIDD',
#  'BLE',
#  'BMNR',
#  'BOTJ',
#  'BOW',
#  'BRDG',
#  'BRR',
#  'BSET',
#  'BST',
#  'BYFC',
#  'BZUN',
#  'CEGX',
#  'CEPT',
#  'CFBK',
#  'CGBD',
#  'CIMN',
#  'CIO',
#  'CMBS',
#  'CMDB',
#  'COF.PRJ',
#  'CPSM',
#  'CSBR',
#  'CSM',
#  'CSPI',
#  'CTBI',
#  'CTEV',
#  ...]
