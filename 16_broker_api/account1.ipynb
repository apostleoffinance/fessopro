# %%
from alpaca.trading.client import TradingClient
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Fetch keys from environment
api_key = os.getenv("API_KEY")
secret_key = os.getenv("SECRET_KEY")

# Connect to Alpaca (set paper=True for paper trading, paper=False for live crypto trading)
trading_client = TradingClient(api_key, secret_key, paper=True)

# Get account details
account = trading_client.get_account()
print(account)
# Out:
# id=UUID('e0c394a4-e5f6-4df8-b51d-6e5f8f670ae1') account_number='PA337CM3CLW9' status=<AccountStatus.ACTIVE: 'ACTIVE'> crypto_status=<AccountStatus.ACTIVE: 'ACTIVE'> currency='USD' buying_power='199587.96' regt_buying_power='199587.96' daytrading_buying_power='0' non_marginable_buying_power='99793.98' cash='99793.98' accrued_fees='0' pending_transfer_out=None pending_transfer_in=None portfolio_value='100116.53' pattern_day_trader=False trading_blocked=False transfers_blocked=False account_blocked=False created_at=datetime.datetime(2024, 11, 14, 16, 14, 45, 303574, tzinfo=TzInfo(UTC)) trade_suspended_by_user=False multiplier='2' shorting_enabled=True equity='100116.53' last_equity='100118.72077335' long_market_value='322.55' short_market_value='0' initial_margin='0' maintenance_margin='0' last_maintenance_margin='0' sma='99793.98' daytrade_count=0 options_buying_power='99793.98' options_approved_level=3 options_trading_level=3

# %%
account.equity
# Out:
# '100116.53'

# %%
import pandas as pd
df=pd.Series(dict(account))
df.to_csv('data.csv')

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest
from alpaca.trading.enums import AssetClass

trading_client = TradingClient(api_key, secret_key)

# search for crypto assets
#search_params = GetAssetsRequest(asset_class=AssetClass.CRYPTO)

search_params = GetAssetsRequest(asset_class=AssetClass.US_EQUITY)

assets = trading_client.get_all_assets(search_params)

# %%
assets
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a137bb6b-4119-4e88-98f8-e712e5c09bbb'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GOLDEN VY BANCSHARES INC Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GVYB',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('c63315d9-ff7f-4452-b16b-e9581079cdf8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Great West Lifeco Inc Ordinary Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GWLIF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('4c937261-6c0a-4258-94f7-0c84068951a8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Engold Mines Ltd Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GWRRF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('ee49dcad-2993-4963-8520-965e7ece8a72'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Great Western Minerals Group, Ltd. Ordinary Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GWMGF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('cd8e596b-4889-4bac-be10-54e46b5cb2af'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Great Wall Motor Company Ltd Ordinary Shares H (China)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GWLLF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('626cc6b6-0a49-4263-8703-29c08fcbd54f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GROWTHPOINT PROPERTIES LTD Ordinary Shares (South Africa)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GWWTF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('a1286e0a-7941-4979-87c0-fe6bb6811d5c'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Gerova Financial Group Ltd Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GVFG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('54b1d14e-1182-4f1d-93d1-ff740c4545d6'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'GATEWAY BK F S B OAKLAND CALIF Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GWBK',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('8c800b8b-5639-4f84-bedc-1cbe6207a3cd'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Goviex Uranium Inc Ordinary Shares Cl A (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GVXXF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('e586f0f5-2093-457a-ad4e-fa95ce140171'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Global Vision Holdings, Inc. Class B Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GVHIB',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('21c7ee08-4bc8-4b59-8d9b-ca64c53595a8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Greenvale Mining N L  Ord Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GVLMF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('f227200d-9469-4de4-9d42-e62505238c96'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Green Energy Enterprises, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GYOG',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('2fcdafdd-5c73-4555-921a-103b2247898f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Guardian Exploration Inc. Common Shares (Canada)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'GXUSF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('
',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('9165c74c-56af-4892-97d3-8e021d24f8ab'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Kudelski SA Cheseaux Sur Lausanne Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KDCXF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('283eba17-9d7d-40fc-8b77-389abe8d5bb8'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Keck Seng Investments Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KCKSF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6fabb2f3-eb4e-4163-977d-4d3353b34fd0'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Kobayashi Pharmaceutical Co Ltd Osaka Ordinary Shares (Japan)',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KBYPF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6c5f8de5-5203-401f-93e9-79293f0bcc79'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Kindcard, Inc. Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KCRD',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('22542f59-4bf6-422a-95ca-81c7a8ecfb3f'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'KCM Holdings Corporation Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KCMH',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('b618376e-6cbb-4e53-8324-ff38fcf9b0e5'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Kobe Steel Ltd Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KBSTF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('86b54c98-c280-4acb-b184-d9421b75b1fa'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Kutcho Copper Corp Ordinary Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KCCFF',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('6790b2aa-f6e6-40f1-9847-c5a39b52fb20'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Kansas City Life Insurance Co Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KCLI',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('deff28ee-c58c-4cb4-80cb-a34216657d86'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'Kid Castle Educational Corporation Common Stock',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KDCE',
#      'tradable': False},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.OTC: 'OTC'>,
#      'fractionable': False,
#      'id': UUID('28978a61-153e-4fa4-833d-d1042d8035ad'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': None,
#      'min_trade_increment': None,
#      'name': 'KBS Real Estate Invt Tr III Inc Common Shares',
#      'price_increment': None,
#      'shortable': False,
#      'status': <AssetStatus.INACTIVE: 'inactive'>,
#      'symbol': 'KBSR',
#      'tradable': False},
#  ...]

# %%
list1=[]

for i in assets:
    list1.append(dict(i))
df=pd.DataFrame(list1)
#df.to_csv('assets.csv')
df
# Out:
#                                          id           asset_class  \
# 0      a137bb6b-4119-4e88-98f8-e712e5c09bbb  AssetClass.US_EQUITY
# 1      c63315d9-ff7f-4452-b16b-e9581079cdf8  AssetClass.US_EQUITY
# 2      4c937261-6c0a-4258-94f7-0c84068951a8  AssetClass.US_EQUITY
# 3      ee49dcad-2993-4963-8520-965e7ece8a72  AssetClass.US_EQUITY
# 4      cd8e596b-4889-4bac-be10-54e46b5cb2af  AssetClass.US_EQUITY
# ...                                     ...                   ...
# 32106  1bd79a4c-40e4-445b-848a-0feeec0579cd  AssetClass.US_EQUITY
# 32107  79320709-15b7-40df-b55e-dcae42788ca2  AssetClass.US_EQUITY
# 32108  a2192ded-0453-47c1-9428-bc023efb35f8  AssetClass.US_EQUITY
# 32109  59576c8b-25c8-4a3c-8259-4467a3c4330c  AssetClass.US_EQUITY
# 32110  8c35598c-38db-4a86-8eb5-619dc075d9f0  AssetClass.US_EQUITY
#
#                    exchange symbol  \
# 0         AssetExchange.OTC   GVYB
# 1         AssetExchange.OTC  GWLIF
# 2         AssetExchange.OTC  GWRRF
# 3         AssetExchange.OTC  GWMGF
# 4         AssetExchange.OTC  GWLLF
# ...                     ...    ...
# 32106    AssetExchange.NYSE   AMPY
# 32107    AssetExchange.NYSE    AMR
# 32108    AssetExchange.NYSE   AMRC
# 32109  AssetExchange.NASDAQ   AMRK
# 32110  AssetExchange.NASDAQ   AMRN
#
#                                                     name  \
# 0                  GOLDEN VY BANCSHARES INC Common Stock
# 1         Great West Lifeco Inc Ordinary Shares (Canada)
# 2                       Engold Mines Ltd Ordinary Shares
# 3      Great Western Minerals Group, Ltd. Ordinary Sh...
# 4      Great Wall Motor Company Ltd Ordinary Shares H...
# ...                                                  ...
# 32106                               Amplify Energy Corp.
# 32107                Alpha Metallurgical Resources, Inc.
# 32108                                     Ameresco, Inc.
# 32109          A-Mark Precious Metals, Inc. Common Stock
# 32110                             Amarin Corporation plc
#
#                      status  tradable  marginable  shortable  easy_to_borrow  \
# 0      AssetStatus.INACTIVE     False       False      False           False
# 1      AssetStatus.INACTIVE     False       False      False           False
# 2      AssetStatus.INACTIVE     False       False      False           False
# 3      AssetStatus.INACTIVE     False       False      False           False
# 4      AssetStatus.INACTIVE     False       False      False           False
# ...                     ...       ...         ...        ...             ...
# 32106    AssetStatus.ACTIVE      True        True       True            True
# 32107    AssetStatus.ACTIVE      True        True       True            True
# 32108    AssetStatus.ACTIVE      True        True       True            True
# 32109    AssetStatus.ACTIVE      True        True       True            True
# 32110    AssetStatus.ACTIVE      True        True      False           False
#
#        fractionable min_order_size min_trade_increment price_increment  \
# 0             False           None                None            None
# 1             False           None                None            None
# 2             False           None                None            None
# 3             False           None                None            None
# 4             False           None                None            None
# ...             ...            ...                 ...             ...
# 32106         False           None                None            None
# 32107          True           None                None            None
# 32108          True           None                None            None
# 32109          True           None                None            None
# 32110         False           None                None            None
#
#        maintenance_margin_requirement                            attributes
# 0                               100.0                                    []
# 1                               100.0                                    []
# 2                               100.0                                    []
# 3                               100.0                                    []
# 4                               100.0                                    []
# ...                               ...                                   ...
# 32106                            30.0                         [has_options]
# 32107                            30.0  [fractional_eh_enabled, has_options]
# 32108                            30.0  [fractional_eh_enabled, has_options]
# 32109                            30.0  [fractional_eh_enabled, has_options]
# 32110                            30.0                         [has_options]
#
# [32111 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32111 entries, 0 to 32110
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              32111 non-null  object
#  1   asset_class                     32111 non-null  object
#  2   exchange                        32111 non-null  object
#  3   symbol                          32111 non-null  object
#  4   name                            32111 non-null  object
#  5   status                          32111 non-null  object
#  6   tradable                        32111 non-null  bool
#  7   marginable                      32111 non-null  bool
#  8   shortable                       32111 non-null  bool
#  9   easy_to_borrow                  32111 non-null  bool
#  10  fractionable                    32111 non-null  bool
#  11  min_order_size                  0 non-null      object
#  12  min_trade_increment             0 non-null      object
#  13  price_increment                 0 non-null      object
#  14  maintenance_margin_requirement  32111 non-null  float64
#  15  attributes                      32111 non-null  object
# dtypes: bool(5), float64(1), object(10)
# memory usage: 2.8+ MB

# %%
df[df['shortable']==True]['symbol'].to_list()
# Out:
# ['LOGC',
#  'DTRUY',
#  'CAJPY',
#  'MBGAF',
#  'WCPRF',
#  'NSANY',
#  'MTHRY',
#  'CKHUY',
#  'AMRX',
#  'AMRZ',
#  'AMS',
#  'AMSC',
#  'AMSF',
#  'AMT',
#  'AMTB',
#  'AMTM',
#  'AMWD',
#  'AMX',
#  'AMZU',
#  'AMZY',
#  'AN',
#  'ANAB',
#  'ANDE',
#  'ANET',
#  'ANF',
#  'ANGI',
#  'ANGL',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANRO',
#  'ANTX',
#  'AOA',
#  'AOD',
#  'AOK',
#  'AOM',
#  'AOMR',
#  'AON',
#  'AOR',
#  'AORT',
#  'AOS',
#  'AOSL',
#  'AOUT',
#  'APA',
#  'APAM',
#  'APD',
#  'APEI',
#  'APG',
#  'APGE',
#  'APH',
#  'API',
#  'APLD',
#  'APLE',
#  'APLS',
#  'APLY',
#  'APO',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APTV',
#  'APWC',
#  'APYX',
#  'AQN',
#  'AQST',
#  'AR',
#  'ARAY',
#  'ARCB',
#  'ARCC',
#  'ARCO',
#  'ARCT',
#  'ARDC',
#  'ARDT',
#  'ARDX',
#  'ARE',
#  'ARES',
#  'ARGX',
#  'ARHS',
#  'ARI',
#  'ARIS',
#  'ARKB',
#  'ARKF',
#  'ARKO',
#  'ARKQ',
#  'ARKR',
#  'ARKW',
#  'ARKX',
#  'ARLO',
#  'ARLP',
#  'ARM',
#  'ARMK',
#  'ARMN',
#  'AROC',
#  'AROW',
#  'ARQ',
#  'ARQT',
#  'ARR',
#  'ARRY',
#  'ARTNA',
#  'ARTW',
#  'ARTY',
#  'ARVN',
#  'ARW',
#  'ARWR',
#  'ARX',
#  'AS',
#  'ASAN',
#  'ASB',
#  'ASC',
#  'ASG',
#  'ASGI',
#  'ASGN',
#  'ASH',
#  'ASHR',
#  'ASHS',
#  'ASIC',
#  'ASIX',
#  'ASLE',
#  'ASM',
#  'ASMB',
#  'ASMG',
#  'ASML',
#  'ASND',
#  'ASO',
#  'ASPI',
#  'ASPN',
#  'ASPS',
#  'ASR',
#  'ASTE',
#  'ASTH',
#  'ASTS',
#  'ASUR',
#  'ASX',
#  'ASYS',
#  'ATAI',
#  'ATEC',
#  'ATEN',
#  'ATEX',
#  'ATGE',
#  'ATH.PRD',
#  'ATHM',
#  'ATI',
#  'ATKR',
#  'ATLC',
#  'ATLO',
#  'ATMU',
#  'ATNI',
#  'ATNM',
#  'ATO',
#  'ATR',
#  'ATRA',
#  'ATRC',
#  'ATRO',
#  'ATS',
#  'ATUS',
#  'ATXS',
#  'ATYR',
#  'AU',
#  'AUB',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AUTL',
#  'AVA',
#  'AVAH',
#  'AVAV',
#  'AVB',
#  'AVBP',
#  'AVD',
#  'AVDE',
#  'AVDL',
#  'AVDV',
#  'AVDX',
#  'AVEM',
#  'AVES',
#  'AVGE',
#  'AVGO',
#  'AVIR',
#  'LKNCY',
#  'AVL',
#  'AVNM',
#  'AVNS',
#  'AVNT',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVSF',
#  'AVT',
#  'AVTR',
#  'AVUS',
#  'AVUV',
#  'AVY',
#  'AWF',
#  'AWI',
#  'AWK',
#  'AWP',
#  'AWR',
#  'AWRE',
#  'AX',
#  'AXGN',
#  'AXL',
#  'AXON',
#  'AXP',
#  'AXR',
#  'AXS',
#  'AXSM',
#  'AXTA',
#  'AXTI',
#  'AYI',
#  'AZN',
#  'AZO',
#  'AZTA',
#  'B',
#  'BA',
#  'BA.PRA',
#  'BAB',
#  'BABA',
#  'BABX',
#  'BAC',
#  'BAC.PRB',
#  'BAC.PRN',
#  'BAC.PRO',
#  'BAC.PRP',
#  'BAFN',
#  'BAH',
#  'BALL',
#  'BAM',
#  'BANC',
#  'BAND',
#  'BANF',
#  'BANR',
#  'BANX',
#  'BAP',
#  'BASE',
#  'BATRA',
#  'BATRK',
#  'BAX',
#  'BB',
#  'BBAR',
#  'BBCA',
#  'BBCP',
#  'BBD',
#  'BBDC',
#  'BBEU',
#  'BBHY',
#  'BBIO',
#  'BBJP',
#  'BBN',
#  'BBSI',
#  'BBUC',
#  'BBVA',
#  'BBW',
#  'BBWI',
#  'BBY',
#  'BC',
#  'BCAL',
#  'BCAT',
#  'BCAX',
#  'BCBP',
#  'BCC',
#  'BCE',
#  'BCH',
#  'BCI',
#  'BCML',
#  'BCO',
#  'BCPC',
#  'BCRX',
#  'BCS',
#  'BCSF',
#  'BCYC',
#  'BDC',
#  'BDN',
#  'BDTX',
#  'BDX',
#  'BE',
#  'BEAM',
#  'BEAT',
#  'BEKE',
#  'BELFA',
#  'BELFB',
#  'BELT',
#  'BEN',
#  'BEP',
#  'BEPC',
#  'BETR',
#  'BF.A',
#  'BF.B',
#  'BFAM',
#  'BFC',
#  'BFH',
#  'BFIN',
#  'BFK',
#  'BFLY',
#  'BFOR',
#  'BFS',
#  'BFST',
#  'BG',
#  'BGB',
#  'BGC',
#  'BGFV',
#  'BGR',
#  'BGRN',
#  'BGS',
#  'BGX',
#  'BH',
#  'BHB',
#  'BHC',
#  'BHE',
#  'BHF',
#  'BHFAN',
#  'BHK',
#  'BHLB',
#  'BHP',
#  'BHR',
#  'BHRB',
#  'BHVN',
#  'BIBL',
#  'BIDU',
#  'BIIB',
#  'BIL',
#  'BILI',
#  'BILL',
#  'BILS',
#  'BINC',
#  'BIO',
#  'BIOA',
#  'BIP',
#  'BIPC',
#  'BIRD',
#  'BIRK',
#  'BIT',
#  'BITB',
#  'BITC',
#  'BITQ',
#  'BITU',
#  'BIV',
#  'BIZD',
#  'BJ',
#  'BJRI',
#  'BK',
#  'BKAG',
#  'BKCH',
#  'BKD',
#  'BKE',
#  'BKH',
#  'BKLC',
#  'BKLN',
#  'BKNG',
#  'BKR',
#  'BKSY',
#  'BKTI',
#  'BKU',
#  'BKUI',
#  'BKV',
#  'BL',
#  'BLBD',
#  'BLCO',
#  'BLD',
#  'BLDE',
#  'BLDP',
#  'BLDR',
#  'BLE',
#  'BLES',
#  'BLFS',
#  'BLFY',
#  'BLK',
#  'BLKB',
#  'BLMN',
#  'BLND',
#  'BLOK',
#  'BLV',
#  'BLX',
#  'BMA',
#  'BMBL',
#  'BME',
#  'BMI',
#  'BMO',
#  'BMR',
#  'BMRC',
#  'BMRN',
#  'BMY',
#  'BN',
#  'BND',
#  'BNDW',
#  'BNDX',
#  'BNED',
#  'BNL',
#  'BNS',
#  'BNTC',
#  'BNTX',
#  'BOC',
#  'BOH',
#  'BOIL',
#  'BOKF',
#  'BOND',
#  'BOOM',
#  'BOOT',
#  'BORR',
#  'BOTZ',
#  'BOX',
#  'BP',
#  'BPOP',
#  'BPRN',
#  'BR',
#  'BRAG',
#  'BRBR',
#  'BRC',
#  'BRCC',
#  'BRDG',
#  'BRFH',
#  'BRK.B',
#  'BRKL',
#  'BRKR',
#  'BRKU',
#  'BRO',
#  'BROS',
#  'BRRR',
#  'BRSL',
#  'BRSP',
#  'BRT',
#  'BRX',
#  'BRY',
#  'BRZE',
#  'BRZU',
#  'BSAC',
#  'BSBK',
#  'BSBR',
#  'BSCQ',
#  'BSCR',
#  'BSCS',
#  'BSCT',
#  'BSCU',
#  'BSCX',
#  'BSET',
#  'BSJP',
#  'BSM',
#  'BSMR',
#  'BST',
#  'BSTZ',
#  'BSV',
#  'BSVN',
#  'BSX',
#  'BSY',
#  'BTBT',
#  'BTC',
#  'BTCI',
#  'BTCO',
#  'BTCW',
#  'BTDR',
#  'BTE',
#  'BTF',
#  'BTG',
#  'BTI',
#  'BTMD',
#  'BTO',
#  'BTSG',
#  'BTU',
#  'BUCK',
#  'BUD',
#  'BUR',
#  'BURL',
#  'BUSE',
#  'BUXX',
#  'BV',
#  'BVFL',
#  'BVN',
#  'BVS',
#  'BW',
#  'BWA',
#  'BWB',
#  'BWIN',
#  'BWLP',
#  'BWMN',
#  'BWX',
#  'BX',
#  'BXC',
#  'BXMT',
#  'BXMX',
#  'BXP',
#  'BXSL',
#  'BY',
#  'BYD',
#  'BYON',
#  'BYRN',
#  'BZ',
#  'BZFD',
#  'BZH',
#  'BZUN',
#  'C',
#  'C.PRN',
#  'CAAP',
#  'CAAS',
#  'CABA',
#  'CABO',
#  'CAC',
#  'CACC',
#  'CACI',
#  'CADE',
#  'CAE',
#  'CAG',
#  'CAH',
#  'CAKE',
#  'CAL',
#  'CALF',
#  'CALM',
#  'CALX',
#  'CANG',
#  'CAPL',
#  'CAR',
#  'CARE',
#  'CARG',
#  'CARR',
#  'CARS',
#  'CART',
#  'CASH',
#  'CASS',
#  'CASY',
#  'CAT',
#  'CATH',
#  'CATO',
#  'CATX',
#  'CATY',
#  'CAVA',
#  'CB',
#  'CBAN',
#  'CBFV',
#  'CBL',
#  'CBLS',
#  'CBNK',
#  'CBOE',
#  'CBRE',
#  'CBRL',
#  'CBSH',
#  'CBT',
#  'CBU',
#  'CBUS',
#  'CBZ',
#  'CC',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCCC',
#  'CCCS',
#  'CCD',
#  'CCEL',
#  'CCEP',
#  'CCI',
#  'CCJ',
#  'CCK',
#  'CCL',
#  'CCNE',
#  'CCO',
#  'CCOI',
#  'CCRD',
#  'CCRN',
#  'CCRV',
#  'CCS',
#  'CCSI',
#  'CCU',
#  'CDE',
#  'CDLX',
#  'CDNA',
#  'CDNS',
#  'CDP',
#  'CDRE',
#  'CDTX',
#  'CDW',
#  'CDX',
#  'CDXS',
#  'CDZI',
#  'CE',
#  'CECO',
#  'CEE',
#  'CEF',
#  'CEFS',
#  'CEFZ',
#  'CEG',
#  'CELC',
#  'CELH',
#  'CENTA',
#  'CENX',
#  'CEPT',
#  'CEPU',
#  'CERS',
#  'CERT',
#  'CEVA',
#  'CF',
#  'CFFI',
#  'CFFN',
#  'CFG',
#  'CFG.PRH',
#  'CFG.PRI',
#  'CFLT',
#  'CFR',
#  'CG',
#  'CGAU',
#  'CGBD',
#  'CGCV',
#  'CGEM',
#  'CGEN',
#  'CGGO',
#  'CGGR',
#  'CGNX',
#  'CGON',
#  'CGTX',
#  'CHAT',
#  'CHAU',
#  'CHCI',
#  'CHCO',
#  'CHCT',
#  'CHD',
#  'CHDN',
#  'CHE',
#  'CHEF',
#  'CHGG',
#  'CHH',
#  'CHIQ',
#  'CHKP',
#  'CHMI',
#  'CHRD',
#  'CHRS',
#  'CHRW',
#  'CHT',
#  'CHTR',
#  'CHW',
#  'CHWY',
#  'CI',
#  'CIB',
#  'CIBR',
#  'CIEN',
#  'CIFR',
#  'CIG',
#  'CIGI',
#  'CIM',
#  'CINF',
#  'CION',
#  'CIVB',
#  'CIVI',
#  'CIX',
#  'CL',
#  'CLAR',
#  'CLB',
#  'CLBK',
#  'CLBT',
#  'CLDX',
#  'CLF',
#  'CLFD',
#  'CLH',
#  'CLIP',
#  'CLLS',
#  'CLM',
#  'CLMB',
#  'CLMT',
#  'CLNE',
#  'CLOI',
#  'CLOV',
#  'CLOZ',
#  'CLPR',
#  'CLPT',
#  'CLS',
#  'CLSK',
#  'CLVT',
#  'CLW',
#  'CLX',
#  'CLYM',
#  'CM',
#  'CMA',
#  'CMBS',
#  'CMC',
#  'CMCL',
#  'CMCO',
#  'CMCSA',
#  'CMDB',
#  'CME',
#  'CMF',
#  'CMG',
#  'CMI',
#  'CMP',
#  'CMPO',
#  'CMPR',
#  'CMPS',
#  'CMPX',
#  'CMRC',
#  'CMRE',
#  'CMS',
#  'CMSD',
#  'CMT',
#  'CMTG',
#  'CNA',
#  'CNC',
#  'CNDT',
#  'CNH',
#  'CNI',
#  'CNK',
#  'CNM',
#  'CNMD',
#  'CNNE',
#  'CNO',
#  'CNOB',
#  'CNP',
#  'CNQ',
#  'CNR',
#  'CNS',
#  'CNTA',
#  'CNVS',
#  'CNX',
#  'CNXC',
#  'CNXN',
#  'COCO',
#  'CODA',
#  'CODI',
#  'COE',
#  'COF',
#  'COF.PRI',
#  'COF.PRJ',
#  'COGT',
#  'COHN',
#  'COHR',
#  'COHU',
#  'COIN',
#  'COIW',
#  'COKE',
#  'COLB',
#  'COLD',
#  'COLL',
#  'COLM',
#  'COLO',
#  'COMM',
#  'COMP',
#  'COMT',
#  'CON',
#  'COO',
#  'COOK',
#  'COOP',
#  'COP',
#  'COPX',
#  'COR',
#  'CORT',
#  'CORZ',
#  'COST',
#  'COTY',
#  'COUR',
#  'COWZ',
#  'COYA',
#  'CP',
#  'CPA',
#  'CPAY',
#  'CPB',
#  'CPF',
#  'CPK',
#  'CPNG',
#  'CPRI',
#  'CPRT',
#  'CPRX',
#  'CPS',
#  'CPSL',
#  'CPSS',
#  'CPT',
#  'CQQQ',
#  'CR',
#  'CRAI',
#  'CRBG',
#  'CRBN',
#  'CRBP',
#  'CRBU',
#  'CRC',
#  'CRCT',
#  'CRD.A',
#  'CRDO',
#  'CREX',
#  'CRF',
#  'CRGX',
#  'CRGY',
#  'CRH',
#  'CRI',
#  'CRIS',
#  'CRK',
#  'CRL',
#  'CRM',
#  'CRMD',
#  'CRMT',
#  'CRNC',
#  'CRNT',
#  'CRNX',
#  'CRON',
#  'CROX',
#  'CRS',
#  'CRSR',
#  'CRUS',
#  'CRVL',
#  'CRVS',
#  'CRWD',
#  'CRWG',
#  'CRWS',
#  'CSAN',
#  'CSB',
#  'CSBR',
#  'CSCO',
#  'CSGP',
#  'CSGS',
#  'CSHI',
#  'CSL',
#  'CSPI',
#  'CSQ',
#  'CSR',
#  'CSTL',
#  'CSTM',
#  'CSV',
#  'CSW',
#  'CSWC',
#  'CSX',
#  'CTA',
#  'CTAS',
#  'CTBB',
#  'CTEF',
#  'CTGO',
#  'CTKB',
#  'CTLP',
#  'CTMX',
#  'CTNM',
#  'CTO',
#  'CTOS',
#  'CTRA',
#  'CTRE',
#  'CTRN',
#  'CTS',
#  'CTSH',
#  'CTSO',
#  'CTVA',
#  'CUBE',
#  'CUBI',
#  'CUK',
#  'CURB',
#  'CURI',
#  'CUZ',
#  'CVBF',
#  'CVCO',
#  'CVE',
#  'CVEO',
#  'CVGI',
#  'CVGW',
#  'CVI',
#  'CVLG',
#  'CVLT',
#  'CVNA',
#  'CVRT',
#  'CVRX',
#  'CVS',
#  'CVX',
#  'CW',
#  'CWAN',
#  'CWB',
#  'CWBC',
#  'CWCO',
#  'CWEB',
#  'CWEN',
#  'CWEN.A',
#  'CWH',
#  'CWK',
#  'CWS',
#  'CWST',
#  'CWT',
#  'CX',
#  'CXDO',
#  'CXM',
#  'CXT',
#  'CXW',
#  'CYBR',
#  'CYD',
#  'CYH',
#  'CYRX',
#  'CYTK',
#  'CZFS',
#  'CZR',
#  'D',
#  'DAC',
#  'DAKT',
#  'DAL',
#  'DAN',
#  'DAR',
#  'DASH',
#  'DAVA',
#  'DAVE',
#  'DAWN',
#  'DAX',
#  'DAY',
#  'DB',
#  'DBB',
#  'DBC',
#  'DBD',
#  'DBEF',
#  'DBI',
#  'DBMF',
#  'DBO',
#  'DBRG',
#  'DBX',
#  'DC',
#  'DCGO',
#  'DCI',
#  'DCO',
#  'DCOM',
#  'DCRE',
#  'DCTH',
#  'DD',
#  'DDD',
#  'DDL',
#  'DDLS',
#  'DDM',
#  'DDOG',
#  'DDS',
#  'DE',
#  'DEA',
#  'DEC',
#  'DECK',
#  'DECU',
#  'DEED',
#  'DEFT',
#  'DEI',
#  'DELL',
#  'DEM',
#  'DENN',
#  'DEO',
#  'DERM',
#  'DES',
#  'DFAC',
#  'DFAE',
#  'DFAI',
#  'DFAR',
#  'DFAS',
#  'DFAT',
#  'DFAU',
#  'DFAX',
#  'DFCA',
#  'DFCF',
#  'DFEM',
#  'DFEV',
#  'DFH',
#  'DFIC',
#  'DFIN',
#  'DFIS',
#  'DFIV',
#  'DFJ',
#  'DFNM',
#  'DFSD',
#  'DFSV',
#  'DFUS',
#  'DFUV',
#  'DG',
#  'DGCB',
#  'DGICA',
#  'DGII',
#  'DGRO',
#  'DGRW',
#  'DGS',
#  'DGX',
#  'DH',
#  'DHC',
#  'DHI',
#  'DHIL',
#  'DHR',
#  'DHS',
#  'DHT',
#  'DIA',
#  'DIAL',
#  'DIG',
#  'DIN',
#  'DINO',
#  'DIOD',
#  'DIS',
#  'DISV',
#  'DIVO',
#  'DJCO',
#  'DJD',
#  'DJIA',
#  'DJP',
#  'DJT',
#  'DK',
#  'DKNG',
#  'DKS',
#  'DLB',
#  'DLO',
#  'DLR',
#  'DLTR',
#  'DLX',
#  'DMAC',
#  'DMB',
#  'DMBS',
#  'DMLP',
#  'DMRC',
#  'DNB',
#  'DNLI',
#  'DNN',
#  'DNOW',
#  'DNTH',
#  'DNUT',
#  'DOC',
#  'DOCN',
#  ...]
